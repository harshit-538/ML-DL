# %% [markdown]
# <a href="https://colab.research.google.com/github/harshit-538/ML-DL/blob/main/9_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **YOLO:**
#   - (YOLO)you look only once
#   - state of the art object detection algorithm.
#   - input if using regular CNN to detect object.
#   - This only works for single object only.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# yolo:
#  - grid on NxN(N = 3,6,9,19,etc...)
#  - for each grid calculate above vector

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#   - Find IOU(Intersection over Union) if multiple objects found
#   - intersection over unit = intersect area/union area
#   - if multipl bounding box then take max
#   - if multiple object center in one grid only then append that vector.

# %% [markdown]
# Darknet-url: https://github.com/AlexeyAB/darknet

# %% [markdown]
# # **Recurrent Neural Network(RNN):**
#   - Use Cases:
#     - RNN it suggest remaining sentence/code.
#     - Translation
#     - Named Entity Recognition(NER)
#     - Sentiment Analysis
#     - All these are sequence completing models.
#     - In this ANN will not work proper.
#
#   - Process one word and from second work processing give me previous output as input.
#   - it helps to preserve sequence and carries previous state.
#   - same neurons in all layers but it is all in one algorithm.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Types of RNN:**
#   - Many to Many RNN:
#     - many input and many output
#   - Sentiment Analysis(Many yo one):
#     - many input and one/fixed output
#   - Music Generation(One to Many):
#     - one input to manu output.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
